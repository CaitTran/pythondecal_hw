# %% [markdown]
# <a href="https://colab.research.google.com/github/CaitTran/pythondecal_hw/blob/main/project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
# Import data from NASA Exoplanet Archive
exoplanets = pd.read_csv('exoplanets.csv',skiprows=98)
exoplanets
# Out:
#          pl_name  hostname    pl_orbper  pl_orbpererr1  pl_orbpererr2  \
# 0       11 Com b    11 Com   323.210000       0.060000      -0.050000
# 1       11 UMi b    11 UMi   516.219970       3.200000      -3.200000
# 2       14 And b    14 And   186.760000       0.110000      -0.120000
# 3       14 Her b    14 Her  1765.038900       1.677090      -1.872560
# 4     16 Cyg B b  16 Cyg B   798.500000       1.000000      -1.000000
# ...          ...       ...          ...            ...            ...
# 5782   ups And b   ups And     4.617033       0.000023      -0.000023
# 5783   ups And c   ups And   241.258000       0.064000      -0.064000
# 5784   ups And d   ups And  1276.460000       0.570000      -0.570000
# 5785   ups Leo b   ups Leo   385.200000       2.800000      -1.300000
# 5786    xi Aql b    xi Aql   136.970000       0.110000      -0.180000
#
#       pl_orbperlim  pl_orbsmax  pl_orbsmaxerr1  pl_orbsmaxerr2  pl_orbsmaxlim  \
# ...

# %%
# Filtered data
data = exoplanets.loc[:,['pl_name', 'pl_orbsmax', 'pl_radj', 'pl_bmassj', 'pl_dens', 'pl_insol', 'pl_eqt', 'st_spectype']]
data
# Out:
#          pl_name  pl_orbsmax  pl_radj  pl_bmassj  pl_dens  pl_insol  pl_eqt  \
# 0       11 Com b    1.178000     1.09    15.4640   14.900       NaN     NaN
# 1       11 UMi b    1.530000     1.09    14.7400   13.800       NaN     NaN
# 2       14 And b    0.775000     1.16     3.5590    2.760       NaN     NaN
# 3       14 Her b    2.774000     1.12     8.0530    7.030       NaN     NaN
# 4     16 Cyg B b    1.660000     1.20     1.7800    1.260       NaN     NaN
# ...          ...         ...      ...        ...      ...       ...     ...
# 5782   ups And b    0.059222     1.25     0.6876    0.438       NaN     NaN
# 5783   ups And c    0.827774     1.10    13.9800   13.100       NaN     NaN
# 5784   ups And d    2.513290     1.11    10.2500    9.170       NaN     NaN
# 5785   ups Leo b    1.180000     1.27     0.5100    0.311       NaN     NaN
# 5786    xi Aql b    0.625000     1.20     1.9410    1.410       NaN     NaN
#
#      st_spectype
# 0         G8 III
# 1         K4 III
# ...
