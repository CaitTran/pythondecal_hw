# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#1 Analyzing Air Quality Data

# %%
#1.1
pd.read_csv("global_air_quality.csv")
df = pd.read_csv("global_air_quality.csv")
df
# Out:
#      IndicatorCode                                          Indicator  \
# 0          SDGPM25  Concentrations of fine particulate matter (PM2.5)
# 1          SDGPM25  Concentrations of fine particulate matter (PM2.5)
# 2          SDGPM25  Concentrations of fine particulate matter (PM2.5)
# 3          SDGPM25  Concentrations of fine particulate matter (PM2.5)
# 4          SDGPM25  Concentrations of fine particulate matter (PM2.5)
# ...            ...                                                ...
# 9445       SDGPM25  Concentrations of fine particulate matter (PM2.5)
# 9446       SDGPM25  Concentrations of fine particulate matter (PM2.5)
# 9447       SDGPM25  Concentrations of fine particulate matter (PM2.5)
# 9448       SDGPM25  Concentrations of fine particulate matter (PM2.5)
# 9449       SDGPM25  Concentrations of fine particulate matter (PM2.5)
#
#      ValueType ParentLocationCode         ParentLocation Location type  \
# 0         text                AFR                 Africa       Country
# 1         text                AMR               Americas       Country
# 2         text                EUR                 Europe       Country
# 3         text                AMR               Americas       Country
# 4         text                AMR               Americas       Country
# ...        ...                ...                    ...           ...
# 9445      text                AMR               Americas       Country
# 9446      text                AMR               Americas       Country
# 9447      text                AFR                 Africa       Country
# 9448      text                AMR               Americas       Country
# 9449      text                EMR  Eastern Mediterranean       Country
#
#      SpatialDimValueCode                                           Location  \
# 0                    KEN                                              Kenya
# 1                    TTO                                Trinidad and Tobago
# 2                    GBR  United Kingdom of Great Britain and Northern I...
# 3                    GRD                                            Grenada
# 4                    BRA                                             Brazil
# ...                  ...                                                ...
# 9445                 BLZ                                             Belize
# 9446                 TTO                                Trinidad and Tobago
# 9447                 KEN                                              Kenya
# 9448                 USA                           United States of America
# 9449                 AFG                                        Afghanistan
#
#      Period type  Period  ...  FactValueUoM FactValueNumericLowPrefix  \
# 0           Year    2019  ...           NaN                       NaN
# 1           Year    2019  ...           NaN                       NaN
# 2           Year    2019  ...           NaN                       NaN
# 3           Year    2019  ...           NaN                       NaN
# 4           Year    2019  ...           NaN                       NaN
# ...          ...     ...  ...           ...                       ...
# 9445        Year    2010  ...           NaN                       NaN
# 9446        Year    2010  ...           NaN                       NaN
# 9447        Year    2010  ...           NaN                       NaN
# 9448        Year    2010  ...           NaN                       NaN
# 9449        Year    2010  ...           NaN                       NaN
#
#      FactValueNumericLow FactValueNumericHighPrefix  FactValueNumericHigh  \
# 0                   6.29                        NaN                 13.74
# 1                   7.44                        NaN                 12.55
# 2                   9.73                        NaN                 10.39
# 3                   7.07                        NaN                 13.20
# 4                   8.23                        NaN                 12.46
# ...                  ...                        ...                   ...
# 9445                3.91                        NaN                 20.28
# 9446                7.80                        NaN                 12.89
# 9447                6.30                        NaN                 13.57
# 9448                9.78                        NaN                 10.11
# 9449               66.17                        NaN                128.40
#
#                      Value  FactValueTranslationID  FactComments  Language  \
# 0       10.01 [6.29-13.74]                     NaN           NaN        EN
# 1       10.02 [7.44-12.55]                     NaN           NaN        EN
# 2       10.06 [9.73-10.39]                     NaN           NaN        EN
# 3       10.08 [7.07-13.20]                     NaN           NaN        EN
# 4       10.09 [8.23-12.46]                     NaN           NaN        EN
# ...                    ...                     ...           ...       ...
# 9445     9.92 [3.91-20.28]                     NaN           NaN        EN
# 9446     9.92 [7.80-12.89]                     NaN           NaN        EN
# 9447     9.94 [6.30-13.57]                     NaN           NaN        EN
# 9448     9.95 [9.78-10.11]                     NaN           NaN        EN
# 9449  92.79 [66.17-128.44]                     NaN           NaN        EN
#
#              DateModified
# 0     2022-08-12 00:00:00
# 1     2022-08-12 00:00:00
# 2     2022-08-12 00:00:00
# 3     2022-08-12 00:00:00
# 4     2022-08-12 00:00:00
# ...                   ...
# 9445  2022-08-12 00:00:00
# 9446  2022-08-12 00:00:00
# 9447  2022-08-12 00:00:00
# 9448  2022-08-12 00:00:00
# 9449  2022-08-12 00:00:00
#
# [9450 rows x 34 columns]

# %%
#1.2
df["PM25_Value"] = df["FactValueNumeric"]
print(df[["FactValueNumeric", "PM25_Value"]])
# Out:
#       FactValueNumeric  PM25_Value
# 0                10.01       10.01
# 1                10.02       10.02
# 2                10.06       10.06
# 3                10.08       10.08
# 4                10.09       10.09
# ...                ...         ...
# 9445              9.92        9.92
# 9446              9.92        9.92
# 9447              9.94        9.94
# 9448              9.95        9.95
# 9449             92.79       92.79
#
# [9450 rows x 2 columns]

# %%
#1.3

df.sort_values(["ParentLocation"])

continent_averages = df.groupby(["ParentLocation"])["PM25_Value"].mean()
continent_averages
# Out:
# ParentLocation
# Africa                   29.812282
# Americas                 14.645728
# Eastern Mediterranean    38.403682
# Europe                   19.244727
# South-East Asia          32.145796
# Western Pacific          15.497559
# Name: PM25_Value, dtype: float64

# %%
df = df.merge(continent_averages, on='ParentLocation', how='left')

# %%
df.rename(columns = {"PM25_Value_x": "PM25_Value", "PM25_Value_y": "Average_PM25"}, inplace = True)

# %%
df
# Out:
#      IndicatorCode                                          Indicator  \
# 0          SDGPM25  Concentrations of fine particulate matter (PM2.5)
# 1          SDGPM25  Concentrations of fine particulate matter (PM2.5)
# 2          SDGPM25  Concentrations of fine particulate matter (PM2.5)
# 3          SDGPM25  Concentrations of fine particulate matter (PM2.5)
# 4          SDGPM25  Concentrations of fine particulate matter (PM2.5)
# ...            ...                                                ...
# 9445       SDGPM25  Concentrations of fine particulate matter (PM2.5)
# 9446       SDGPM25  Concentrations of fine particulate matter (PM2.5)
# 9447       SDGPM25  Concentrations of fine particulate matter (PM2.5)
# 9448       SDGPM25  Concentrations of fine particulate matter (PM2.5)
# 9449       SDGPM25  Concentrations of fine particulate matter (PM2.5)
#
#      ValueType ParentLocationCode         ParentLocation Location type  \
# 0         text                AFR                 Africa       Country
# 1         text                AMR               Americas       Country
# 2         text                EUR                 Europe       Country
# 3         text                AMR               Americas       Country
# 4         text                AMR               Americas       Country
# ...        ...                ...                    ...           ...
# 9445      text                AMR               Americas       Country
# 9446      text                AMR               Americas       Country
# 9447      text                AFR                 Africa       Country
# 9448      text                AMR               Americas       Country
# 9449      text                EMR  Eastern Mediterranean       Country
#
#      SpatialDimValueCode                                           Location  \
# 0                    KEN                                              Kenya
# 1                    TTO                                Trinidad and Tobago
# 2                    GBR  United Kingdom of Great Britain and Northern I...
# 3                    GRD                                            Grenada
# 4                    BRA                                             Brazil
# ...                  ...                                                ...
# 9445                 BLZ                                             Belize
# 9446                 TTO                                Trinidad and Tobago
# 9447                 KEN                                              Kenya
# 9448                 USA                           United States of America
# 9449                 AFG                                        Afghanistan
#
#      Period type  Period  ...  FactValueNumericLow FactValueNumericHighPrefix  \
# 0           Year    2019  ...                 6.29                        NaN
# 1           Year    2019  ...                 7.44                        NaN
# 2           Year    2019  ...                 9.73                        NaN
# 3           Year    2019  ...                 7.07                        NaN
# 4           Year    2019  ...                 8.23                        NaN
# ...          ...     ...  ...                  ...                        ...
# 9445        Year    2010  ...                 3.91                        NaN
# 9446        Year    2010  ...                 7.80                        NaN
# 9447        Year    2010  ...                 6.30                        NaN
# 9448        Year    2010  ...                 9.78                        NaN
# 9449        Year    2010  ...                66.17                        NaN
#
#      FactValueNumericHigh                 Value  FactValueTranslationID  \
# 0                   13.74    10.01 [6.29-13.74]                     NaN
# 1                   12.55    10.02 [7.44-12.55]                     NaN
# 2                   10.39    10.06 [9.73-10.39]                     NaN
# 3                   13.20    10.08 [7.07-13.20]                     NaN
# 4                   12.46    10.09 [8.23-12.46]                     NaN
# ...                   ...                   ...                     ...
# 9445                20.28     9.92 [3.91-20.28]                     NaN
# 9446                12.89     9.92 [7.80-12.89]                     NaN
# 9447                13.57     9.94 [6.30-13.57]                     NaN
# 9448                10.11     9.95 [9.78-10.11]                     NaN
# 9449               128.40  92.79 [66.17-128.44]                     NaN
#
#       FactComments  Language         DateModified  PM25_Value  Average_PM25
# 0              NaN        EN  2022-08-12 00:00:00       10.01     29.812282
# 1              NaN        EN  2022-08-12 00:00:00       10.02     14.645728
# 2              NaN        EN  2022-08-12 00:00:00       10.06     19.244727
# 3              NaN        EN  2022-08-12 00:00:00       10.08     14.645728
# 4              NaN        EN  2022-08-12 00:00:00       10.09     14.645728
# ...            ...       ...                  ...         ...           ...
# 9445           NaN        EN  2022-08-12 00:00:00        9.92     14.645728
# 9446           NaN        EN  2022-08-12 00:00:00        9.92     14.645728
# 9447           NaN        EN  2022-08-12 00:00:00        9.94     29.812282
# 9448           NaN        EN  2022-08-12 00:00:00        9.95     14.645728
# 9449           NaN        EN  2022-08-12 00:00:00       92.79     38.403682
#
# [9450 rows x 36 columns]

# %%
#1.4
df.sort_values(["Average_PM25"], ascending = False)
# Out:
#      IndicatorCode                                          Indicator  \
# 9449       SDGPM25  Concentrations of fine particulate matter (PM2.5)
# 7049       SDGPM25  Concentrations of fine particulate matter (PM2.5)
# 7053       SDGPM25  Concentrations of fine particulate matter (PM2.5)
# 7056       SDGPM25  Concentrations of fine particulate matter (PM2.5)
# 7061       SDGPM25  Concentrations of fine particulate matter (PM2.5)
# ...            ...                                                ...
# 5587       SDGPM25  Concentrations of fine particulate matter (PM2.5)
# 7970       SDGPM25  Concentrations of fine particulate matter (PM2.5)
# 817        SDGPM25  Concentrations of fine particulate matter (PM2.5)
# 5593       SDGPM25  Concentrations of fine particulate matter (PM2.5)
# 4725       SDGPM25  Concentrations of fine particulate matter (PM2.5)
#
#      ValueType ParentLocationCode         ParentLocation Location type  \
# 9449      text                EMR  Eastern Mediterranean       Country
# 7049      text                EMR  Eastern Mediterranean       Country
# 7053      text                EMR  Eastern Mediterranean       Country
# 7056      text                EMR  Eastern Mediterranean       Country
# 7061      text                EMR  Eastern Mediterranean       Country
# ...        ...                ...                    ...           ...
# 5587      text                AMR               Americas       Country
# 7970      text                AMR               Americas       Country
# 817       text                AMR               Americas       Country
# 5593      text                AMR               Americas       Country
# 4725      text                AMR               Americas       Country
#
#      SpatialDimValueCode            Location Period type  Period  ...  \
# 9449                 AFG         Afghanistan        Year    2010  ...
# 7049                 JOR              Jordan        Year    2012  ...
# 7053                 JOR              Jordan        Year    2012  ...
# 7056                 JOR              Jordan        Year    2012  ...
# 7061                 TUN             Tunisia        Year    2012  ...
# ...                  ...                 ...         ...     ...  ...
# 5587                 CAN              Canada        Year    2014  ...
# 7970                 HND            Honduras        Year    2011  ...
# 817                  DOM  Dominican Republic        Year    2019  ...
# 5593                 DMA            Dominica        Year    2014  ...
# 4725                 BRB            Barbados        Year    2014  ...
#
#       FactValueNumericLow FactValueNumericHighPrefix FactValueNumericHigh  \
# 9449                66.17                        NaN               128.40
# 7049                21.84                        NaN                27.78
# 7053                22.03                        NaN                28.20
# 7056                22.76                        NaN                28.37
# 7061                17.34                        NaN                35.64
# ...                   ...                        ...                  ...
# 5587                 7.67                        NaN                 8.18
# 7970                17.44                        NaN                32.72
# 817                  4.71                        NaN                11.97
# 5593                 5.47                        NaN                11.37
# 4725                 6.80                        NaN                14.13
#
#                      Value  FactValueTranslationID  FactComments  Language  \
# 9449  92.79 [66.17-128.44]                     NaN           NaN        EN
# 7049   24.79 [21.84-27.78]                     NaN           NaN        EN
# 7053   24.94 [22.03-28.20]                     NaN           NaN        EN
# 7056   25.27 [22.76-28.37]                     NaN           NaN        EN
# 7061   25.40 [17.34-35.64]                     NaN           NaN        EN
# ...                    ...                     ...           ...       ...
# 5587      7.92 [7.67-8.18]                     NaN           NaN        EN
# 7970   24.29 [17.44-32.72]                     NaN           NaN        EN
# 817      7.76 [4.71-11.97]                     NaN           NaN        EN
# 5593     8.02 [5.47-11.37]                     NaN           NaN        EN
# 4725    10.00 [6.80-14.13]                     NaN           NaN        EN
#
#              DateModified  PM25_Value  Average_PM25
# 9449  2022-08-12 00:00:00       92.79     38.403682
# 7049  2022-08-12 00:00:00       24.79     38.403682
# 7053  2022-08-12 00:00:00       24.94     38.403682
# 7056  2022-08-12 00:00:00       25.27     38.403682
# 7061  2022-08-12 00:00:00       25.40     38.403682
# ...                   ...         ...           ...
# 5587  2022-08-12 00:00:00        7.92     14.645728
# 7970  2022-08-12 00:00:00       24.29     14.645728
# 817   2022-08-12 00:00:00        7.76     14.645728
# 5593  2022-08-12 00:00:00        8.02     14.645728
# 4725  2022-08-12 00:00:00       10.00     14.645728
#
# [9450 rows x 36 columns]

# %%
highest_pollution = df.sort_values(["Average_PM25"], ascending = False)
highest_pollution_list = highest_pollution[0:10]
highest_pollution_list

#Answer: The continent with the highest average air pollution is the Eastern Mediterranean.
#It doesn't really surprise me because in developing countries, the fuel available is often dirtier fuels such as coal and natural materials. That would naturally cause more air pollution.
# Out:
#      IndicatorCode                                          Indicator  \
# 9449       SDGPM25  Concentrations of fine particulate matter (PM2.5)
# 7049       SDGPM25  Concentrations of fine particulate matter (PM2.5)
# 7053       SDGPM25  Concentrations of fine particulate matter (PM2.5)
# 7056       SDGPM25  Concentrations of fine particulate matter (PM2.5)
# 7061       SDGPM25  Concentrations of fine particulate matter (PM2.5)
# 4375       SDGPM25  Concentrations of fine particulate matter (PM2.5)
# 7072       SDGPM25  Concentrations of fine particulate matter (PM2.5)
# 7073       SDGPM25  Concentrations of fine particulate matter (PM2.5)
# 7074       SDGPM25  Concentrations of fine particulate matter (PM2.5)
# 7076       SDGPM25  Concentrations of fine particulate matter (PM2.5)
#
#      ValueType ParentLocationCode         ParentLocation Location type  \
# 9449      text                EMR  Eastern Mediterranean       Country
# 7049      text                EMR  Eastern Mediterranean       Country
# 7053      text                EMR  Eastern Mediterranean       Country
# 7056      text                EMR  Eastern Mediterranean       Country
# 7061      text                EMR  Eastern Mediterranean       Country
# 4375      text                EMR  Eastern Mediterranean       Country
# 7072      text                EMR  Eastern Mediterranean       Country
# 7073      text                EMR  Eastern Mediterranean       Country
# 7074      text                EMR  Eastern Mediterranean       Country
# 7076      text                EMR  Eastern Mediterranean       Country
#
#      SpatialDimValueCode     Location Period type  Period  ...  \
# 9449                 AFG  Afghanistan        Year    2010  ...
# 7049                 JOR       Jordan        Year    2012  ...
# 7053                 JOR       Jordan        Year    2012  ...
# 7056                 JOR       Jordan        Year    2012  ...
# 7061                 TUN      Tunisia        Year    2012  ...
# 4375                 OMN         Oman        Year    2015  ...
# 7072                 SDN        Sudan        Year    2012  ...
# 7073                 JOR       Jordan        Year    2012  ...
# 7074                 LBY        Libya        Year    2012  ...
# 7076                 LBY        Libya        Year    2012  ...
#
#       FactValueNumericLow FactValueNumericHighPrefix FactValueNumericHigh  \
# 9449                66.17                        NaN               128.40
# 7049                21.84                        NaN                27.78
# 7053                22.03                        NaN                28.20
# 7056                22.76                        NaN                28.37
# 7061                17.34                        NaN                35.64
# 4375                22.53                        NaN                59.10
# 7072                12.58                        NaN                50.05
# 7073                19.47                        NaN                34.22
# 7074                11.06                        NaN                44.05
# 7076                10.58                        NaN                44.68
#
#                      Value  FactValueTranslationID  FactComments  Language  \
# 9449  92.79 [66.17-128.44]                     NaN           NaN        EN
# 7049   24.79 [21.84-27.78]                     NaN           NaN        EN
# 7053   24.94 [22.03-28.20]                     NaN           NaN        EN
# 7056   25.27 [22.76-28.37]                     NaN           NaN        EN
# 7061   25.40 [17.34-35.64]                     NaN           NaN        EN
# 4375   35.84 [22.53-59.10]                     NaN           NaN        EN
# 7072   25.74 [12.58-50.05]                     NaN           NaN        EN
# 7073   25.79 [19.47-34.22]                     NaN           NaN        EN
# 7074   25.95 [11.06-44.05]                     NaN           NaN        EN
# 7076   25.99 [10.58-44.68]                     NaN           NaN        EN
#
#              DateModified  PM25_Value  Average_PM25
# 9449  2022-08-12 00:00:00       92.79     38.403682
# 7049  2022-08-12 00:00:00       24.79     38.403682
# 7053  2022-08-12 00:00:00       24.94     38.403682
# 7056  2022-08-12 00:00:00       25.27     38.403682
# 7061  2022-08-12 00:00:00       25.40     38.403682
# 4375  2022-08-12 00:00:00       35.84     38.403682
# 7072  2022-08-12 00:00:00       25.74     38.403682
# 7073  2022-08-12 00:00:00       25.79     38.403682
# 7074  2022-08-12 00:00:00       25.95     38.403682
# 7076  2022-08-12 00:00:00       25.99     38.403682
#
# [10 rows x 36 columns]

# %%
#1.5
new_df = df[["Location", "ParentLocation", "PM25_Value", "Average_PM25"]]
new_df.to_csv("PM25_Averages_by_Location.csv")

# %%
#2 Planets, planets, planets!

# %%
import seaborn as sns

# %%
sns.load_dataset('planets')
# Out:
#                method  number  orbital_period   mass  distance  year
# 0     Radial Velocity       1      269.300000   7.10     77.40  2006
# 1     Radial Velocity       1      874.774000   2.21     56.95  2008
# 2     Radial Velocity       1      763.000000   2.60     19.84  2011
# 3     Radial Velocity       1      326.030000  19.40    110.62  2007
# 4     Radial Velocity       1      516.220000  10.50    119.47  2009
# ...               ...     ...             ...    ...       ...   ...
# 1030          Transit       1        3.941507    NaN    172.00  2006
# 1031          Transit       1        2.615864    NaN    148.00  2007
# 1032          Transit       1        3.191524    NaN    174.00  2007
# 1033          Transit       1        4.125083    NaN    293.00  2008
# 1034          Transit       1        4.187757    NaN    260.00  2008
#
# [1035 rows x 6 columns]

# %%
pnts = sns.load_dataset('planets')
pnts
# Out:
#                method  number  orbital_period   mass  distance  year
# 0     Radial Velocity       1      269.300000   7.10     77.40  2006
# 1     Radial Velocity       1      874.774000   2.21     56.95  2008
# 2     Radial Velocity       1      763.000000   2.60     19.84  2011
# 3     Radial Velocity       1      326.030000  19.40    110.62  2007
# 4     Radial Velocity       1      516.220000  10.50    119.47  2009
# ...               ...     ...             ...    ...       ...   ...
# 1030          Transit       1        3.941507    NaN    172.00  2006
# 1031          Transit       1        2.615864    NaN    148.00  2007
# 1032          Transit       1        3.191524    NaN    174.00  2007
# 1033          Transit       1        4.125083    NaN    293.00  2008
# 1034          Transit       1        4.187757    NaN    260.00  2008
#
# [1035 rows x 6 columns]

# %%
#2.1
plot = sns.scatterplot(data = pnts, x = pnts["orbital_period"], y = pnts["mass"], hue = pnts["method"])
plot.set(title ="Planets' Mass Correlation to Orbital Period")
plot.set_xlabel("Orbital Period (Unit: Earth Days)")
plot.set_ylabel("Mass (Unit: Jupiter Masses)")
plot.set_xscale("log")
plot.legend(bbox_to_anchor = (1.1, 1))

# %%
#2.2
#Attempt 1 (Ignore pls)
bar_plot = sns.barplot(data = pnts, x = pnts["year"], y = pnts["number"],hue = pnts["method"])
bar_plot.set(title = "Planets Discovered per Year (Grouped by Discovery Method)")
bar_plot.set_xlabel("Year")
bar_plot.set_ylabel("Exoplanets Discovered")
# Out:
# Text(0, 0.5, 'Exoplanets Discovered')

# %%
#Attempt 2
hist_plot = sns.histplot(data = pnts, x = pnts["year"],hue = pnts["method"], multiple = "stack")
hist_plot.set(title = "Planets Discovered per Year (Grouped by Discovery Method)")
hist_plot.set_xlabel("Year")
hist_plot.set_ylabel("Exoplanets Discovered")
# Out:
# Text(0, 0.5, 'Exoplanets Discovered')
